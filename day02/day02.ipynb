# %%
def part1(file):
    invalid = 0
    with open(file, 'r') as f:
        ids = f.read().strip().split(',')
        for pid in ids:
            start, stop = [int(x) for x in pid.split('-')]
            for num in range(start, stop+1):
                snum = str(num)
                l = len(snum)
                if l % 2 == 0:
                    if bool(re.fullmatch(r"(\d+)\1", snum)):
                        invalid += num
                    
    return invalid

# %%
def part2(file):
    invalid = 0
    with open(file, 'r') as f:
        ids = f.read().strip().split(',')
        for pid in ids:
            start, stop = [int(x) for x in pid.split('-')]
            for num in range(start, stop+1):
                snum = str(num)
                if bool(re.fullmatch(r"(\d+)\1+", snum)):
                    invalid += num
                
    return invalid

# %%
import re

file = 'data.txt'

sum1 = part1(file)
sum2 = part2(file)

print(f"sum1: {sum1}, sum2: {sum2}")
# Out:
# sum1: 23039913998, sum2: 35950619148
